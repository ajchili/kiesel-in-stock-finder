# %%
from bs4 import BeautifulSoup
import requests
import json

request = requests.get("https://www.kieselguitars.com/in-stocks")
soup = BeautifulSoup(request.text, "html.parser")

data = soup.find(id="__NEXT_DATA__")
instrument_collection = json.loads(data.get_text())["props"]["pageProps"]["instrumentCollection"]
in_stock_instruments = json.loads(instrument_collection)

specs_on_in_stock_instruments = {}

for instrument in in_stock_instruments:
	for spec in instrument["specs"]:
		if spec in ["_ts"]:
			continue
		if "value" not in instrument["specs"][spec]:
			continue

		if spec not in specs_on_in_stock_instruments:
			specs_on_in_stock_instruments[spec] = set()

		specs_on_in_stock_instruments[spec].add(instrument["specs"][spec]["value"])

# %%
specs_on_in_stock_instruments

spec_category_mapping = {
	'price': 'general',
	'model': 'general',
	'modelName': 'general',
	'bridge': 'hardware',
	'serialNumber': None,
	'stringCount': 'general',
	'dexterity': 'general',
	'multiscale': 'general',
	'case': 'general',
	'construction': 'general',
	'scaleLength': 'general',
	'bevel': 'body',
	'body': 'body',
	'bodyConstruction': 'body',
	'topWood': 'body',
	'woodTreatment': 'body',
	'threePieceBody': 'body',
	'finish': 'body',
	'customShopFinish': 'body',
	'crackle': 'body',
	'cali': 'body',
	'burstEdges': 'body',
	'topCoat': 'body',
	'pickguard': 'body',
	'rearFinish': 'body',
	'binding': 'body',
	'headstock': 'neck',
	'headstockOverlay': 'neck',
	'headstockFinish': 'neck',
	'trussRodCover': 'neck',
	'neck': 'neck',
	'neckFinish': 'neck',
	'neckProfile': 'neck',
	'numFrets': 'neck',
	'fingerboard': 'neck',
	'fingerboardRadius': 'neck',
	'frets': 'neck',
	'inlays': 'neck',
	'inlayMaterial': 'neck',
	'hardware': 'hardware',
	'logo': 'neck',
	'strapButtons': 'hardware',
	'tuners': 'neck',
	'knobs': 'hardware',
	'strings': 'hardware',
	'pickupConfiguration': 'electronics',
	'bridgePickup': 'electronics',
	'neckPickup': 'electronics',
	'middlePickup': 'electronics',
	'pickupColor': 'electronics',
	'polePieces': 'electronics',
	'midi': None,
	'controls': 'electronics',
	'notes': None,
	'optionFifty': None,
	'nonReturnable': None,
	'extra': None,
	'optionFiftyOne': None,
	'weight': None,
}

normalized_filters = {
	'other': {}
}

for spec in specs_on_in_stock_instruments:
	category = spec_category_mapping.get(spec, None)

	if category is None:
		normalized_filters['other'][spec] = specs_on_in_stock_instruments[spec]
		continue

	if category not in normalized_filters:
		normalized_filters[category] = {}

	if spec == 'price':
		normalized_filters[category][spec] = list(map(lambda num: float(num), specs_on_in_stock_instruments[spec]))
	else:
		normalized_filters[category][spec] = specs_on_in_stock_instruments[spec]

normalized_filters
# Out:
# {'other': {'serialNumber': {'122974',
#    '122977',
#    '144282',
#    '144284',
#    '144808',
#    '145761',
#    '146830',
#    '150459',
#    '151099',
#    '152252',
#    '153130',
#    '154235',
#    '154451',
#    '154457',
#    '154498',
#    '154508',
#    '154515',
#    '154523',
#    '154524',
#    '154537',
#    '154544',
#    '154545',
#    '154553',
#    '154562',
#    '154592',
#    '154593',
#    '154594',
#    '155032',
#    '155033',
#    '156501',
#    '156671',
#    '156745',
#    '156883',
#    '157582',
#    '157608',
#    '157609',
#    '157880',
#    '159111',
#    '159199',
#    '159206',
#    '159373',
#    '159453',
#    '159456',
#    '159515',
#    '159543',
#    '159547',
#    '159642',
#    '159644',
#    '159765',
#    '159796',
#    '159801',
#    '159829',
#    '159841',
#    '159850',
#    '159868',
#    '159937',
#    '159940',
#    '160667',
#    '160738',
#    '161290',
#    '162338',
#    '162518',
#    '162523',
#    '162528',
#    '162566',
#    '162910',
#    '162927',
#    '162930',
#    '163136',
#    '163180',
#    '163187',
#    '163189',
#    '163587',
#    '163600',
#    '163626',
#    '163784',
#    '163826',
#    '163834',
#    '163877',
#    '163987',
#    '163992',
#    '167026',
#    '167840',
#    '167841',
#    '167843',
#    '167844',
#    '167845',
#    '167867',
#    '167883',
#    '167898',
#    '167899',
#    '167918',
#    '167919',
#    '167920',
#    '167932',
#    '167933',
#    '167935',
#    '167937',
#    '167976',
#    '167982',
#    '167984',
#    '167991',
#    '167999',
#    '171015',
#    '171019',
#    '171026',
#    '171028',
#    '171061',
#    '171064',
#    '68057',
#    '68090'},
#   'midi': {''},
#   'notes': {'',
#    '1 VOLUME 2 TONE KNOBS',
#    '37" MULSTISCALE',
#    '5A POPLAR TOP, BLACK KTB FINGERBOARD',
#    'ACOUSTIC SADDLES EQUIPPED,',
#    'AQUA DEEP BINDING',
#    'ARTIST LOANER, LIGHT WEAR UNDER STRINGS BY BRIDGE PU,',
#    'ARTSIT LOANER - 2 REAR STRAP BUTTONS',
#    'ARTSIT LOANER, ALMOST NO WEAR AT ALL',
#    'Artist Loaner - Pick wear above pickups and near knobs',
#    'Artist loaner, heavy wear on pickguard and light wear on body',
#    'BONUS: LIGHT FLAME IN NECK',
#    'CUSTOM SHOP FINISH',
#    'EVO J FRETS',
#    'Endorser Loaner',
#    'Endorser Loaner - Minor Ding in Body and Headstock',
#    'Endorser Loaner - Minor Wear',
#    'Endorser Loaner, Very Light Wear On rear Of Body',
#    'FLAMED REDWOOD TOP AND HEADSTOCK,',
#    'GREY DENIM FINISH,',
#    'HIPSHOT DE-TUNER INSTALLED',
#    'IMPERIAL FINISH,',
#    'KRG TEXTURED SPLATTER',
#    'LIGHT BLACK DENIM FINISH,',
#    'PURPLEHEART BACKPLATES, 5A ',
#    'RED OVER BLACK LOGO',
#    'RED TO GOLD COLOR SHIFT FINISH',
#    'SLIGHT FLAME IN NECK',
#    'SLIGHT FLAME IN NECK!',
#    'SLIGHT FLAME IN NECK! DONT MISS THIS ONE',
#    'TEXTURED SPLATTER WHITE OVER BLACK FINISH,',
#    'V BURST PATTERN PAINT JOB'},
#   'optionFifty': {''},
#   'nonReturnable': {False, True, 'true'},
#   'extra': {False},
#   '': {''},
#   'optionFiftyOne': {''},
#   'weight': {'11.2 lbs'}},
#  'general': {'price': [2799.0,
#    2149.0,
#    2234.0,
#    2300.0,
#    3589.0,
#    3699.0,
#    2000.0,
#    2549.0,
#    3199.0,
#    3200.0,
#    3100.0,
#    3099.0,
#    2900.0,
#    2939.0,
#    3149.0,
#    2450.0,
#    2499.0,
#    2049.0,
#    2859.0,
#    2069.0,
#    2399.0,
#    2599.0,
#    3329.0,
#    2299.0,
#    2350.0,
#    2079.0,
#    1849.0,
#    1749.0,
#    2999.0,
#    2849.0,
#    1899.0,
#    2249.0,
#    2200.0,
#    1949.0,
#    2199.0,
#    3689.0,
#    1999.0,
#    4400.0,
#    2500.0,
#    3299.0,
#    2179.0,
#    4399.0,
#    2949.0,
#    3049.0,
#    2349.0,
#    3599.0,
#    3399.0,
#    2449.0,
#    2699.0,
#    1799.0,
#    1900.0,
#    3400.0,
#    2100.0],
#   'model': {'A26C',
#    'A26H',
#    'A26X',
#    'A27H',
#    'A2B4',
#    'A2BM5',
#    'A2M6',
#    'A2M7',
#    'A2M8',
#    'A6C',
#    'A6E',
#    'A6G',
#    'A6H',
#    'A6X',
#    'A7H',
#    'A7X',
#    'A8E',
#    'AJ7X',
#    'AM7',
#    'ATS7X',
#    'BV6X',
#    'BV7',
#    'BV7X',
#    'BVM7',
#    'CC275',
#    'CR6',
#    'CS3S',
#    'CS3X',
#    'D6G',
#    'D6H',
#    'D7E',
#    'D7X',
#    'DC600C',
#    'DCM7X',
#    'DDM4',
#    'FG1',
#    'H6C',
#    'H7H',
#    'HD6',
#    'HD6X',
#    'HH2',
#    'HH2X',
#    'JB5',
#    'JBYY',
#    'L6X',
#    'LM6X',
#    'MJM4',
#    'MO7X',
#    'NA6C',
#    'NA6H',
#    'NA6X',
#    'NA7H',
#    'NA7X',
#    'O7X',
#    'OM6',
#    'RV69K',
#    'S6E',
#    'S6H',
#    'SCB6M',
#    'SCB6X',
#    'SCB7H',
#    'TB4',
#    'TV6X',
#    'ULTRA-V-C',
#    'ULTRAVM',
#    'V220C',
#    'V7',
#    'V7X',
#    'VB4',
#    'VB5',
#    'VBM8',
#    'VM7',
#    'ZB4',
#    'ZB5',
#    'ZB6',
#    'ZM7'},
#   'modelName': {'A2',
#    'A2 ARIES 2',
#    'A2 BASS',
#    'A2 BOLT-ON',
#    'AL JOSEPH SIGNATURE SERIES',
#    'ALLAN HOLDSWORTH SIGNATURE SERIES',
#    'ARIES 2 BASS',
#    'ARIES BOLT-ON',
#    'ARIES NECK-THROUGH',
#    'ARIES TITANIUM SERIES',
#    'COLE ROLLAND SIGNATURE SERIES',
#    'CRAIG CHAQUICO SIGNATURE SERIES',
#    'CS3',
#    'DC',
#    'DELOS',
#    'DELOS HEADLESS',
#    'DUSTIN DAVIDSON SIGNATURE SERIES',
#    'FRANK GAMBALE 1 SIGNATURE SERIES',
#    'HYPERDRIVE',
#    'J-BASS',
#    'JASON BECKER YIN YANG',
#    'LEE MCKINNEY SIGNATURE SERIES',
#    'LEIA',
#    'MARC OKUBO SIGNATURE SERIES',
#    'MODERN J-BASS',
#    'OSIRIS',
#    'ROY VOGT SIGNATURE SERIES',
#    'SCB',
#    'SOLO',
#    'THANOS',
#    'TYPE-V',
#    'ULTRA-V',
#    'V220',
#    'VADER BASS',
#    'VADER BOLT-ON',
#    'VADER NECK-THROUGH',
#    'ZEUS',
#    'ZEUS BASS'},
#   'stringCount': {'4', '5', '6', '7', '8'},
#   'dexterity': {'', 'L'},
#   'multiscale': {'', 'MULTISCALE'},
#   'case': {'HC19', 'SC10', 'SC8', 'SC9'},
#   'construction': {'BOLT-ON', 'NECK-THROUGH', 'SET NECK'},
#   'scaleLength': {'2475', '250', '255', '265', '270', '300', '340', 'M'}},
#  'hardware': {'bridge': {'',
#    'EVERTUNE',
#    'FLOYD ROSE TREMOLO',
#    'GOTOH 510 TREMOLO',
#    'HEADLESS MULTISCALE BRIDGE',
#    'HEADLESS MULTISCALE TREMOLO',
#    'HEADLESS TREMOLO BRIDGE',
#    'HIPSHOT FIXED BRIDGE',
#    'HIPSHOT/KIESEL TREMOLO SYSTEM',
#    'MULTISCALE TREMOLO',
#    'TUNE-O-MATIC BRIDGE AND STRING THRU BODY',
#    'TUNE-O-MATIC BRIDGE WITH STOP TAILPIECE'},
#   'hardware': {'BC', 'CHR', 'G'},
#   'strapButtons': {'', 'SL'},
#   'knobs': {'AK', 'DK', 'KNB', 'KNW', 'MHC', 'PK', 'WK'},
#   'strings': {'009', '1253E', '4011', '46'}},
#  'body': {'bevel': {'', 'BV', 'BVD'},
#   'body': {'ALD', 'ASH', 'ASH1', 'KOA', 'LMB', 'MAH', 'RASH', 'RASH1'},
#   'bodyConstruction': {'', 'CMB'},
#   'topWood': {'',
#    '5PBT',
#    'AT',
#    'FT',
#    'LMBT',
#    'MT',
#    'PBT',
#    'QT',
#    'QT-5',
#    'RET',
#    'SM',
#    'UM',
#    'ZT'},
#   'woodTreatment': {'', 'AAT', 'BOA'},
#   'threePieceBody': {'', '3PB'},
#   'finish': {'',
#    'AG',
#    'B',
#    'BR',
#    'DPW',
#    'FFBLK',
#    'FFTB',
#    'GB',
#    'GM',
#    'HP',
#    'KRG',
#    'MLB',
#    'MM',
#    'ODG',
#    'P',
#    'PB',
#    'PG',
#    'PL',
#    'PSGP',
#    'PUR',
#    'R',
#    'SB',
#    'T',
#    'TB',
#    'TBC',
#    'TD',
#    'TG',
#    'THY',
#    'TMG',
#    'TNB',
#    'TP',
#    'TPK',
#    'TQ',
#    'TQB',
#    'TR',
#    'TS',
#    'TT',
#    'TW',
#    'TY',
#    'W',
#    'WW',
#    'Y'},
#   'customShopFinish': {''},
#   'crackle': {'', 'CF'},
#   'cali': {'', 'CALI', 'RCALI'},
#   'burstEdges': {'', 'BST', 'TBST'},
#   'topCoat': {'CG', 'CS', 'RTF'},
#   'pickguard': {'', 'BG', 'RP', 'SBG', 'WG', 'WPG'},
#   'rearFinish': {'', 'BGB', 'RNC'},
#   'binding': {'', 'BBE', 'BBEB', 'DBBEB'}},
#  'neck': {'headstock': {'',
#    '624',
#    '6IN',
#    '6INR',
#    '725',
#    '7IN',
#    '7INR',
#    '7PH',
#    '7PHR',
#    '7PTH',
#    '8PTH',
#    'CH4',
#    'CH5',
#    'CTH',
#    'GT6',
#    'GT6R',
#    'GT7',
#    'GT7R',
#    'GTB4',
#    'GTB4R',
#    'GTB5R',
#    'H33',
#    'PTH',
#    'PTHR',
#    'TH'},
#   'headstockOverlay': {'',
#    'APH',
#    'BMNH',
#    'EPH',
#    'FPH',
#    'HPH',
#    'MPH',
#    'PBPH',
#    'QPH',
#    'REPH',
#    'SMPH',
#    'UMPH',
#    'ZPH'},
#   'headstockFinish': {'', 'APH', 'NPH', 'PH'},
#   'trussRodCover': {'', 'TCB', 'TCD', 'TCH', 'TCP', 'TCW'},
#   'neck': {'3MM',
#    '3MP',
#    '3MRM',
#    '3MW',
#    '3WB',
#    '3WM',
#    '3WP',
#    '5LM',
#    '5ML',
#    '5MP',
#    '5MW',
#    '5WH',
#    '5WM',
#    '5WP',
#    '7MWH',
#    '7WPM',
#    'FMN',
#    'LMBN',
#    'MAHN',
#    'MAPN',
#    'RFMN',
#    'RMN',
#    'WALN'},
#   'neckFinish': {'CSN', 'PGN', 'PSN', 'TN'},
#   'neckProfile': {'', 'THNN'},
#   'numFrets': {'22F', '24F'},
#   'fingerboard': {'BMF',
#    'EF',
#    'EFB',
#    'FMF',
#    'MF',
#    'PME',
#    'RBMF',
#    'RDB',
#    'REF',
#    'RFMF',
#    'RMF',
#    'RWF',
#    'ZWF'},
#   'fingerboardRadius': {'', 'R10', 'R12', 'R1216', 'R14', 'R20'},
#   'frets': {'6100', 'EVO', 'EVOJ', 'NFR', 'STF', 'STJF', 'STRF'},
#   'inlayMaterial': {'', 'IA', 'IAB', 'IAG', 'IAP', 'IAR', 'IAW', 'ILL', 'IMP'},
#   'inlays': {'',
#    'IB',
#    'ICR',
#    'ICSD',
#    'ID',
#    'IDIA',
#    'IFG',
#    'IKD',
#    'IKSD',
#    'IKSR',
#    'ILM',
#    'IOD',
#    'IR',
#    'ISOD',
#    'ISOR',
#    'MPCC',
#    'NIN'},
#   'logo': {'ABL',
#    'BL',
#    'DSBS',
#    'DSLB',
#    'DSLG',
#    'DSLK',
#    'DSLS',
#    'DSLW',
#    'GL',
#    'MPL',
#    'RL',
#    'WL'},
#   'tuners': {'', 'WPB'}},
#  'electronics': {'pickupConfiguration': {'', 'CAP', 'HH', 'HSS', 'SSS'},
#   'bridgePickup': {'',
#    'ACF',
#    'EMG',
#    'HB2',
#    'JVA',
#    'KBB',
#    'KHB',
#    'KLB',
#    'KMI',
#    'KMS',
#    'KPA',
#    'KRH',
#    'KRJ',
#    'KT3',
#    'PIB',
#    'PMB',
#    'PTB',
#    'SCP'},
#   'neckPickup': {'',
#    'ACF',
#    'JVAN',
#    'KBN',
#    'KBS',
#    'KFN',
#    'KHN',
#    'KLN',
#    'KLS',
#    'KMS',
#    'KPA',
#    'KRHN',
#    'KRJN',
#    'KT3',
#    'NPD',
#    'PEN',
#    'SCPN'},
#   'middlePickup': {'', 'KBS', 'KLS', 'KMS', 'KT3'},
#   'pickupColor': {'',
#    '400',
#    '404',
#    '405',
#    '40BR',
#    '40K',
#    '40P',
#    '40R',
#    '40SB',
#    '41K',
#    'PCB',
#    'PCC',
#    'PCG'},
#   'polePieces': {'', 'PPB', 'PPC', 'PPG'},
#   'controls': {'', 'DGP', 'DTC', 'DTMV', 'VT2'}}}

# %%
nums = ['123', '456', '789']
list(map(lambda num: int(num), nums))
# Out:
# [123, 456, 789]
