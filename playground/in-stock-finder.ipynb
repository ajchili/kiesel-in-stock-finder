# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
request = requests.get("https://www.kieselguitars.com/in-stocks")
soup = BeautifulSoup(request.text, "html.parser")

# %%
data = soup.find(id="__NEXT_DATA__")
instrument_collection = json.loads(data.get_text())["props"]["pageProps"]["instrumentCollection"]
in_stock_instruments = json.loads(instrument_collection)

# %%
specs_on_in_stock_instruments = {}

for instrument in in_stock_instruments:
	for spec, details in instrument.get("specs", {}).items():
		if spec in ["_ts"]:
			continue
		
		if not isinstance(details, dict) or "value" not in details:
			continue

		if spec not in specs_on_in_stock_instruments:
			specs_on_in_stock_instruments[spec] = set()

		specs_on_in_stock_instruments[spec].add(details.get("value"))

# poor mans JSON encoding for sets
for spec in specs_on_in_stock_instruments:
	specs_on_in_stock_instruments[spec] = list(specs_on_in_stock_instruments[spec])

specs_on_in_stock_instruments
# Out:
# {'price': ['2499',
#   '3089',
#   '2449',
#   '2200',
#   '2549',
#   '2799',
#   '1999',
#   '3647',
#   '2199',
#   '4999',
#   '1899',
#   '3599',
#   '6199',
#   '2049',
#   '2039',
#   '2999',
#   '2339',
#   '2849',
#   '1699',
#   '2379',
#   '3159',
#   '2309',
#   '3099',
#   '1949',
#   '2299',
#   '5349',
#   '3699',
#   '3199',
#   '2099',
#   '1997',
#   '3449',
#   '3299',
#   '1888',
#   '2749',
#   '3399',
#   '4174',
#   '2950',
#   '2959',
#   '2279',
#   '2699',
#   '2149',
#   '2349',
#   '3169',
#   '2100',
#   '2229',
#   '2779',
#   '2649',
#   '2599',
#   '2399',
#   '2249',
#   '2300',
#   '3059',
#   '2689'],
#  'model': ['A26C',
#   'CS6X',
#   'SL6H',
#   'TM6',
#   'V6X',
#   'A2BM5',
#   'KV6X',
#   'JB24',
#   'JB5',
#   'HH2',
#   'A2M8',
#   'CS624M',
#   'SCB6H',
#   'T6H',
#   'ZM6',
#   'IC5',
#   'A26H',
#   'LS6',
#   'DC600X',
#   'AP4',
#   'A6H',
#   'BV6',
#   'A28H ',
#   'JBYY',
#   'BVM8',
#   'JB4',
#   'ZBM5',
#   'H6X',
#   'DCM7',
#   'LYRA6H ',
#   'A7E',
#   'LM6X',
#   'DDM4',
#   'A6G',
#   'V6',
#   'HH2X',
#   'KV6H',
#   'A6C',
#   'ZBM4',
#   'HD6',
#   'DC600H',
#   'PB4',
#   'S6H',
#   'JB200C',
#   'M6',
#   'Z6',
#   'OM7',
#   'C6X',
#   'MJM4',
#   'ZB5',
#   'H6H',
#   'D6G',
#   'A26X',
#   'VB4',
#   'CS6M',
#   'A6X ',
#   'HD6X',
#   'D6H',
#   'CT624X',
#   'O6X',
#   'LYRA6H',
#   'RS',
#   'CT6M',
#   'NA26X',
#   'A6X',
#   'A7H',
#   'Z6X'],
#  'modelName': ['SOLO',
#   'JASON BECKER TRIBUTE SERIES',
#   'VADER NECK-THROUGH',
#   'HYPERDRIVE',
#   'A2 ARIES 2',
#   'ZEUS BASS',
#   'ARIES BOLT-ON',
#   'DELOS HEADLESS',
#   'LEE MCKINNEY SIGNATURE SERIES',
#   'JASON BECKER NUMBERS GUITAR',
#   'OSIRIS',
#   'JASON BECKER YIN YANG',
#   'VADER BASS',
#   'DUSTIN DAVIDSON SIGNATURE SERIES',
#   'A2 NECK-THROUGH',
#   'P-BASS',
#   'VANQUISH',
#   'SOPHIE LLOYD SIGNATURE SERIES',
#   'A2',
#   'MODERN J-BASS',
#   'SCB',
#   'DELOS',
#   'ZEUS',
#   'ICON',
#   'LIGHTSPEED',
#   'CT6',
#   'AARON PATRICK SIGNATURE SERIES',
#   'A2 BASS',
#   'CRESCENT',
#   'LYRA',
#   'CS6',
#   'J-BASS',
#   'ALLAN HOLDSWORTH SIGNATURE SERIES',
#   'RETRO SOLO',
#   'THEOS',
#   'VADER BOLT-ON',
#   'DC',
#   'TIM MILLER SIGNATURE SERIES'],
#  'bridge': ['',
#   'H',
#   'C',
#   'E',
#   'SOLO SADDLE BRIDGE',
#   'HEADLESS TREMOLO BRIDGE',
#   'HEADLESS MULTISCALE BRIDGE',
#   'FLOYD ROSE TREMOLO',
#   'HIPSHOT/KIESEL TREMOLO SYSTEM',
#   'HIPSHOT FIXED BRIDGE',
#   'GOTOH 510 TREMOLO',
#   'EVERTUNE',
#   'TUNE-O-MATIC BRIDGE AND STRING THRU BODY'],
#  'serialNumber': ['167749',
#   '167590',
#   '167748',
#   '167399',
#   '167855',
#   '171193',
#   '167648',
#   '161611',
#   '167733',
#   '154707',
#   '154785',
#   '167406',
#   '167129',
#   '154786',
#   '164910',
#   '162952',
#   '167754',
#   '164915',
#   '154784',
#   '155304',
#   '167420',
#   '167041',
#   '145480',
#   '167639',
#   '143467',
#   '164924',
#   '167642',
#   '171314',
#   '163255',
#   '171300',
#   '167644',
#   '154757',
#   '167723',
#   '167177',
#   '167374',
#   '167497',
#   '154745',
#   '154713',
#   '167359',
#   '161446',
#   '167705',
#   '167498',
#   '154579',
#   '143072',
#   '167760',
#   '171337',
#   '167560',
#   '171321',
#   '163133',
#   '167628',
#   '171377',
#   '159872',
#   '154703',
#   '167684',
#   '171356',
#   '171268',
#   '158714',
#   '167551',
#   '154756',
#   '167668',
#   '167550',
#   '167702',
#   '167775',
#   '167771',
#   '167527',
#   '156757',
#   '171334',
#   '167699',
#   '171397',
#   '167774',
#   '115104',
#   '167933',
#   '162941',
#   '155308',
#   '171232',
#   '141814',
#   '154765',
#   '154027',
#   '159058',
#   '167611',
#   '155805',
#   '163254',
#   '154705',
#   '171370',
#   '167726',
#   '158718',
#   '167311',
#   '162139',
#   '171343',
#   '167631',
#   '158724',
#   '140918',
#   '167727',
#   '171256',
#   '167716',
#   '167671',
#   '167745',
#   '167999',
#   '167674',
#   '167719'],
#  'stringCount': ['', '7', '4', '5', '6', '8'],
#  'dexterity': ['', 'L'],
#  'multiscale': ['', 'MULTISCALE'],
#  'case': ['', 'SC10', 'SC8', 'SC9'],
#  'construction': ['', 'NECK-THROUGH', 'BOLT-ON', 'SET NECK'],
#  'scaleLength': ['250', '', '340', '270', '255', '2475', '265', '300', 'M'],
#  'bevel': ['', 'BV', 'BVD'],
#  'body': ['ASH1', 'WAL', 'ASH', 'RASH1', 'ALD', 'RASH', 'MAH', 'LMB'],
#  'bodyConstruction': ['', 'CMB'],
#  'topWood': ['',
#   'UM',
#   'QT-5',
#   'QT-7',
#   'FT',
#   'AT',
#   'FW',
#   'PBT',
#   'UM-5',
#   'RET',
#   'QT',
#   'MT',
#   'SM'],
#  'woodTreatment': ['', 'AAT'],
#  'threePieceBody': ['', '3PB'],
#  'finish': ['',
#   'MALIBU',
#   'KRG',
#   'JMBF',
#   'R',
#   'Y',
#   'OOA',
#   'SDK',
#   'PB',
#   'TY',
#   'TOB',
#   'TB',
#   'GB',
#   'LB',
#   'TW',
#   'DA',
#   'PG',
#   'PL',
#   'RM',
#   'MLO',
#   'TQB',
#   'TD',
#   'DT',
#   'IMPERIAL',
#   'T',
#   'TQ',
#   'BR',
#   'OOW',
#   'CSF',
#   'TG',
#   'AG',
#   'MFS',
#   'SFG',
#   'B',
#   'GT',
#   'TO',
#   'DV',
#   'TBC',
#   'THY',
#   'HPYY',
#   'SOLANA',
#   'SWB',
#   'TR',
#   'WW',
#   'TP'],
#  'customShopFinish': ['',
#   'SPECIAL BLACK CALI FINISH',
#   'CUSTOM CASEY NEON ORANGE METALLIC'],
#  'bloodSplatter': ['', 'BSFT', 'SFT'],
#  'crackle': ['', 'CF'],
#  'cali': ['', 'CALI'],
#  'burstEdges': ['', 'TBST', 'BST'],
#  'topCoat': ['CG', 'TF', 'RTF', 'CS'],
#  'pickguard': ['', 'SBG', 'WPG', 'BG', 'WG'],
#  'rearFinish': ['', 'BGB', 'RNC', 'BBB'],
#  'binding': ['', 'DBBEB', 'BBEB', 'DBBE', 'BBE'],
#  'headstock': ['',
#   'PTHR',
#   'GTB4',
#   '725',
#   'GTB4R',
#   '8PTHR',
#   'HR33',
#   'GTB6R',
#   'CH4',
#   'GT6',
#   'IPH5',
#   '6INR',
#   '7PTHR',
#   'GTB5R',
#   'H33',
#   '7INR',
#   'GT6R',
#   'PTH',
#   '624',
#   'CH5',
#   '7PH',
#   'CTH',
#   '6IN'],
#  'headstockOverlay': ['', 'QPH', 'UMPH', 'SMPH', 'FWPH', 'PBPH', 'FPH', 'APH'],
#  'headstockFinish': ['', 'NPH', 'PH'],
#  'trussRodCover': ['', 'TCP', 'TCW', 'TCB', 'TCD', 'TC1'],
#  'neck': ['5ML',
#   '3WM',
#   '3MW',
#   'WALN',
#   '3MM',
#   '5MW',
#   '5MH',
#   'RMN',
#   'MAHN',
#   '5WM',
#   'FMN',
#   'RFMN',
#   '5LM',
#   'MAPN',
#   '3MP',
#   '3WP',
#   'LMBN'],
#  'neckFinish': ['TN', 'PGN', 'CGN'],
#  'neckProfile': ['', 'THKN', 'THNN'],
#  'numFrets': ['20F', '22F', '24F'],
#  'fingerboard': ['PME',
#   'MF',
#   'RDB',
#   'FMF',
#   'BMF',
#   'EFB',
#   'REF',
#   'RMF',
#   'EF',
#   'RWF',
#   'ZWF',
#   'RFMF',
#   'RBMF'],
#  'fingerboardRadius': ['R14', 'R20', 'R1216', 'R10', 'R12'],
#  'frets': ['EVOJ', 'STF', 'STJF', 'EVO', 'F'],
#  'inlayMaterial': ['', 'IAB', 'IAW', 'ILL', 'IMP', 'IA', 'IAG', 'IAR'],
#  'inlays': ['',
#   'IKSR',
#   'ISOR',
#   'IYY',
#   'ID',
#   'NIN',
#   'ISOD',
#   'ILM',
#   'IR',
#   'IOD',
#   'IB',
#   'IKSD',
#   'ICSD',
#   'IK',
#   'IDIA'],
#  'hardware': ['CHR', 'BC', 'G'],
#  'logo': ['',
#   'DSLK',
#   'GL',
#   'DSLW',
#   'DSBG',
#   'DSBS',
#   'DSLG',
#   'BL',
#   'CL-WL',
#   'WL',
#   'ABL',
#   'DSLB',
#   'DSLS'],
#  'strapButtons': ['', 'SL'],
#  'nut': ['', 'IVN'],
#  'tuners': ['', 'WPB'],
#  'knobs': ['KNW', '', 'AK', 'DK', 'PK', 'MHC', 'KNB'],
#  'strings': ['', '46', '009', '4011'],
#  'pickupConfiguration': ['', 'HSS', 'HH', 'CAP', 'KT3', 'SSS'],
#  'bridgePickup': ['',
#   'PMB',
#   'KRH',
#   'KHB',
#   'KT3',
#   'KBB',
#   'PIB',
#   'HB2',
#   'KBS',
#   'RSBP',
#   'M22',
#   'KMI',
#   'KPA',
#   'KLB',
#   'P90',
#   'ACF',
#   'JVA',
#   'PTB',
#   'KMS'],
#  'neckPickup': ['',
#   'KBS',
#   'PEN',
#   'KPA',
#   'KBN',
#   'KMS',
#   'JVAN',
#   'RSP',
#   'KLS',
#   'P90',
#   'KRHN',
#   'SCPN',
#   'KLN',
#   'KHN',
#   'ACF',
#   'KT3'],
#  'middlePickup': ['', 'KMS', 'KLS', 'KBS', 'KT3'],
#  'pickupColor': ['', '404', 'PCB', 'PCG', '40PSBP', '402', '400', '405'],
#  'polePieces': ['', 'PPG', 'PPB', 'PPC'],
#  'midi': [''],
#  'controls': ['', 'VT2', 'DGP', 'DTMV'],
#  'notes': ['',
#   'CUSTOM 3 COLOR SPLATTER, LAVENDER,BLUE AND CLASSIC WHITE OVER TROPIC',
#   'CHAMBERED BODY, CHEVRON FLAMED TOP, ARTIST LOANER',
#   'BLACK TEXTURED SPLATTER FINISH, SLIGHT FLAME IN FINGERBOARD,',
#   'ARTIST LOANER: MINOR SCRATCHES AND DINGS ON BODY, WEAR ON NECK, LIGHT BLACK KTB, DEEP AQUA FLAME',
#   'DUNCAN P90 LOADED, CUSTOM CONTROLS 1 VOL 1 3-WAY TOGGLE,',
#   'LIGHT BLUE CALI BURST BACK AND SIDES',
#   'GREEN KIESEL TREATED BOARD,',
#   'BONUS SLIGHT FLAME IN NECK,',
#   'ACOUSTIC SADDLES INSTALLED, PURPLE HEART REAR COVER PLATE, ARTIST LOANER LIGHT WEAR',
#   'ARTIST LOANER, SURFACE WEAR ON PICKGUARD, VERY SLIGHT WEAR TO REST OF GTR, AQUA FLAKE',
#   'ACOUSTIC SADDLES EQUIPPED,',
#   'ACOUSTIC SADDLES, EBONY REAR COVER PLATE, TREM PLATE EBONY',
#   'TRANS PINK WITH PURPLE BURST',
#   'BLACK DENIM CALI FINISH, 1 PIECE TOP ',
#   'ARTIST LOANER: LIGHT SURFACE SCRATCHES',
#   'LIMITED HOT PINK/BLUE YING YANG RUN',
#   '5A BURL TOP WITH REVERSE MONSTERBURST FINISH',
#   'SPECIAL CUSTOM WITH GOTOH TREM AND DUNCAN P90S',
#   'ARTIST LOANER, WEAR BELOW PICKUPS AND SIDE EDGE,',
#   'EXTENDED SCALE 26.5 INCH',
#   'WHITE DOTS WITH GREEN CRESCENT,',
#   'STUNNING WALNUT NECK'],
#  'optionFifty': [''],
#  'nonReturnable': [False, True],
#  'extra': [False],
#  '': [''],
#  'optionFiftyOne': [''],
#  'neck Profile': ['NONE']}

# %%
desired_instruments = []

desired_specs = [
	{ "neckProfile": { "value": "THNN" }, "stringCount": { "value": "6" } }
]

for instrument in in_stock_instruments:
	available = True

	for variant in instrument["variants"]:
		if 'availableForSale' in variant["node"].keys() and variant["node"]["availableForSale"] == False:
			available = False
			break

	if not available:
		continue
	
	for desired_spec in desired_specs:
		is_match = True

		for spec in desired_spec:
			if instrument["specs"][spec]["value"] != desired_spec[spec]["value"]:
				is_match = False
				break

		if is_match:
			desired_instruments.append(instrument)

list(map(lambda instrument : f'https://www.kieselguitars.com/in-stock/{instrument["specs"]["serialNumber"]["value"]}', desired_instruments))
# Out:
# ['https://www.kieselguitars.com/in-stock/154579',
#  'https://www.kieselguitars.com/in-stock/154784',
#  'https://www.kieselguitars.com/in-stock/154785',
#  'https://www.kieselguitars.com/in-stock/154786',
#  'https://www.kieselguitars.com/in-stock/171343',
#  'https://www.kieselguitars.com/in-stock/171377',
#  'https://www.kieselguitars.com/in-stock/154713',
#  'https://www.kieselguitars.com/in-stock/167129',
#  'https://www.kieselguitars.com/in-stock/167497',
#  'https://www.kieselguitars.com/in-stock/171256',
#  'https://www.kieselguitars.com/in-stock/155304',
#  'https://www.kieselguitars.com/in-stock/145480',
#  'https://www.kieselguitars.com/in-stock/155308',
#  'https://www.kieselguitars.com/in-stock/158724',
#  'https://www.kieselguitars.com/in-stock/167771',
#  'https://www.kieselguitars.com/in-stock/154703',
#  'https://www.kieselguitars.com/in-stock/154705',
#  'https://www.kieselguitars.com/in-stock/154707',
#  'https://www.kieselguitars.com/in-stock/158714',
#  'https://www.kieselguitars.com/in-stock/167699',
#  'https://www.kieselguitars.com/in-stock/167748',
#  'https://www.kieselguitars.com/in-stock/167855',
#  'https://www.kieselguitars.com/in-stock/171314',
#  'https://www.kieselguitars.com/in-stock/161611',
#  'https://www.kieselguitars.com/in-stock/167374',
#  'https://www.kieselguitars.com/in-stock/167639',
#  'https://www.kieselguitars.com/in-stock/167760']
